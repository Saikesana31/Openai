# %%
import os 
import openai
from dotenv import load_dotenv

# %%
## changes are made and reflected properly

# %%
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
openai.api_key = openai_api_key

# %%
import pandas as pd
models = pd.DataFrame(openai.Model.list()['data'])
models
# Out:
#                               id object     created         owned_by
# 0                     gpt-4-0613  model  1686588896           openai
# 1                          gpt-4  model  1687882411           openai
# 2                  gpt-3.5-turbo  model  1677610602           openai
# 3             gpt-5.1-codex-mini  model  1763007109           system
# 4            gpt-5.1-chat-latest  model  1762547951           system
# ..                           ...    ...         ...              ...
# 101  gpt-5-search-api-2025-10-14  model  1760043960           system
# 102            gpt-3.5-turbo-16k  model  1683758102  openai-internal
# 103                        tts-1  model  1681940951  openai-internal
# 104                    whisper-1  model  1677532384  openai-internal
# 105       text-embedding-ada-002  model  1671217299  openai-internal
#
# [106 rows x 4 columns]

# %%
# chatCompletion API

prompt = "What is the capital of the moon?"

response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt }
    ]
)

print(response.choices[0]['message']['content'])
# Out:
# The moon does not have a capital because it is not a country. It is a natural satellite that orbits the Earth.

# %%
prompt1 = "hello how are you?"
prompt2 = 'i am 25 years old & i am a programmer'
prompt3 = 'tell me about me'

response1 = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt1 },
        {"role": "user", "content": prompt2 },
        {"role": "user", "content": prompt3 }
    ]
)

print(response1.choices[0]['message']['content'])
# Out:
# Based on the information you provided, you are 25 years old and work as a programmer. Is there anything specific you would like to know or talk about?

# %% [markdown]
# ### Parameters

# %%
prompt = "What is python? "

response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt }
    ],
    max_tokens=25
)

print(response.choices[0]['message']['content'])
# Out:
# Python is a widely used, high-level programming language known for its readability and versatility. It supports multiple programming paradigms,

# %%
prompt = "What is python? "

response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt }
    ],
    temperature=0.6
)

print(response.choices[0]['message']['content'])
# Out:
# Python is a high-level, interpreted programming language known for its simplicity and readability. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python is widely used for web development, data analysis, artificial intelligence, scientific computing, and more. It has a large standard library and a thriving community of developers, making it one of the most popular programming languages in the world.

# %%
prompt = "What is python? "

response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt }
    ],
    n=2
)

print(f'responese_1: {response.choices[0]['message']['content']}')
print(f'responese_2: {response.choices[1]['message']['content']}')
# Out:
# responese_1: Python is a versatile and widely-used programming language known for its simplicity and readability. It can be used for a variety of purposes, including web development, data analysis, artificial intelligence, scientific computing, and more. Python has a large standard library and an active community of users, making it a popular choice for both beginners and experienced programmers.
# responese_2: Python is a high-level, interpreted programming language known for its simplicity and readability. It is versatile and widely used for web development, data analysis, artificial intelligence, automation, and more. Python supports a variety of programming paradigms, including procedural, object-oriented, and functional programming.

# %%
prompt = "give me hindi translation of the following text: the movie is amazing "


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt }
    ],
    temperature=0.6
)

print(response.choices[0]['message']['content'])
# Out:
# फिल्म बहुत शानदार है।

# %%
prompt = "give me a python code for adding two numbers? "

response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt }
    ],
    temperature=0.6
)

print(response.choices[0]['message']['content'])
# Out:
# Certainly! Here is a simple Python code that adds two numbers entered by the user:
#
# ```python
# # Get input from user
# num1 = float(input("Enter first number: "))
# num2 = float(input("Enter second number: "))
#
# # Add the two numbers
# result = num1 + num2
#
# # Display the result
# print("The sum of", num1, "and", num2, "is:", result)
# ```
#
# You can copy and paste this code into a Python interpreter or editor to run it.

# %%
## using completion API

prompt = "what is python?"

response = openai.Completion.create(
    model="babbage-002",
    prompt=prompt,
    temperature=0.6,
    max_tokens=25 
)

print(response.choices[0].text)
# Out:
#  it is a programming language. what is the purpose of python? to create a fast and reliable programming language that can be embedded
